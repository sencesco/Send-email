# %% [markdown]
# **How Does Email work?**
#
# When we send an email, The structure and path like a picture below. So the SMTP like a postman
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Now (yeras 2023) hotmaill change to smtp.outlook.com**
# =
